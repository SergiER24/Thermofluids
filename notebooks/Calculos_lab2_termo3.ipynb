# %%
#Imports
import pandas as pd
import msoffcrypto
from io import BytesIO
import gender_guesser.detector as gender
from unidecode import unidecode
import re
from dateutil.relativedelta import relativedelta
import matplotlib.pyplot as plt
import numpy as np

# %%
t = np.array([0, 60, 120, 180, 240, 300])

P1 = 29.02
P2 = 40.59
P3 = 58.00

dT = 0.05

base_1 = np.array([22.20, 19.50, 18.40, 17.20, 15.50, 14.60])
punta_1 = np.array([22.30, 19.20, 18.10, 17.40, 15.80, 14.40])
superficie_1 = np.array([22.30, 19.10, 18.00, 17.50, 16.10, 13.90])
aire_1 = np.array([21.90, 18.80, 18.10, 17.60, 14.50, 14.30])

base_2 = np.array([20.50, 20.10, 18.80, 17.40, 15.50, 15.80])
punta_2 = np.array([20.70, 19.40, 18.20, 17.90, 15.90, 15.60])
superficie_2 = np.array([21.00, 19.30, 18.20, 17.40, 16.00, 14.70])
aire_2 = np.array([21.90, 19.40, 18.00, 17.40, 15.30, 15.10])

base_3 = np.array([20.90, 20.40, 18.20, 17.00, 16.80, 16.50])
punta_3 = np.array([21.50, 20.20, 18.40, 16.60, 16.60, 16.30])
superficie_3 = np.array([21.60, 20.20, 18.40, 16.70, 16.70, 16.40])
aire_3 = np.array([21.90, 20.10, 18.50, 17.00, 16.90, 16.20])

def graficar(y1, y2, y3, titulo, ylabel):
    plt.figure(figsize=(9, 6))
    plt.errorbar(t, y1, yerr=dT, marker='o', capsize=10, label=f'{P1:.2f} W')
    plt.errorbar(t, y2, yerr=dT, marker='o', capsize=10, label=f'{P2:.2f} W')
    plt.errorbar(t, y3, yerr=dT, marker='o', capsize=10, label=f'{P3:.2f} W')
    plt.xlabel('Tiempo [s]')
    plt.ylabel(ylabel)
    plt.title(titulo)
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

graficar(base_1, base_2, base_3,
         'Comportamiento de la temperatura en la base de la aleta',
         'Temperatura [°C]')

graficar(punta_1, punta_2, punta_3,
         'Comportamiento de la temperatura en la punta de la aleta',
         'Temperatura [°C]')

graficar(superficie_1, superficie_2, superficie_3,
         'Comportamiento de la temperatura en la superficie de la aleta',
         'Temperatura [°C]')

graficar(aire_1, aire_2, aire_3,
         'Comportamiento de la temperatura del aire en los alrededores',
         'Temperatura [°C]')

# %%
t = np.array([0, 60, 120, 180, 240, 300])
dt = 1
dT = 0.05

P1 = 29.02
P2 = 40.59
P3 = 58.00

base_1 = np.array([22.20, 19.50, 18.40, 17.20, 15.50, 14.60])
punta_1 = np.array([22.30, 19.20, 18.10, 17.40, 15.80, 14.40])
superficie_1 = np.array([22.30, 19.10, 18.00, 17.50, 16.10, 13.90])
aire_1 = np.array([21.90, 18.80, 18.10, 17.60, 14.50, 14.30])

base_2 = np.array([20.50, 20.10, 18.80, 17.40, 15.50, 15.80])
punta_2 = np.array([20.70, 19.40, 18.20, 17.90, 15.90, 15.60])
superficie_2 = np.array([21.00, 19.30, 18.20, 17.40, 16.00, 14.70])
aire_2 = np.array([21.90, 19.40, 18.00, 17.40, 15.30, 15.10])

base_3 = np.array([20.90, 20.40, 18.20, 17.00, 16.80, 16.50])
punta_3 = np.array([21.50, 20.20, 18.40, 16.60, 16.60, 16.30])
superficie_3 = np.array([21.60, 20.20, 18.40, 16.70, 16.70, 16.40])
aire_3 = np.array([21.90, 20.10, 18.50, 17.00, 16.90, 16.20])

def graficar_potencia(t, base, punta, superficie, aire, potencia):
    plt.figure(figsize=(9, 6))
    plt.errorbar(t, base, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=3, label='Base de la aleta')
    plt.errorbar(t, punta, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=3, label='Punta de la aleta')
    plt.errorbar(t, superficie, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=3, label='Superficie de la aleta')
    plt.errorbar(t, aire, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=3, label='Aire alrededor')
    plt.xlabel('Tiempo [s]')
    plt.ylabel('Temperatura [°C]')
    plt.title(f'Comportamiento térmico para P = {potencia:.2f} W')
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.show()

graficar_potencia(t, base_1, punta_1, superficie_1, aire_1, P1)
graficar_potencia(t, base_2, punta_2, superficie_2, aire_2, P2)
graficar_potencia(t, base_3, punta_3, superficie_3, aire_3, P3)

# %%
t = np.array([0, 60, 120, 180, 240, 300])
dt = 1
dT = 0.05
P1 = 29.02
P2 = 40.59
P3 = 57.97
base_1 = np.array([22.20, 19.50, 18.40, 17.20, 15.50, 14.60])
punta_1 = np.array([22.30, 19.20, 18.10, 17.40, 15.80, 14.40])
superficie_1 = np.array([22.30, 19.10, 18.00, 17.50, 16.10, 13.90])
aire_1 = np.array([21.90, 18.80, 18.10, 17.60, 14.50, 14.30])

base_2 = np.array([20.50, 20.10, 18.80, 17.40, 15.50, 15.80])
punta_2 = np.array([20.70, 19.40, 18.20, 17.90, 15.90, 15.60])
superficie_2 = np.array([21.00, 19.30, 18.20, 17.40, 16.00, 14.70])
aire_2 = np.array([21.90, 19.40, 18.00, 17.40, 15.30, 15.10])

base_3 = np.array([20.90, 20.40, 18.20, 17.00, 16.80, 16.50])
punta_3 = np.array([21.50, 20.20, 18.40, 16.60, 16.60, 16.30])
superficie_3 = np.array([21.60, 20.20, 18.40, 16.70, 16.70, 16.40])
aire_3 = np.array([21.90, 20.10, 18.50, 17.00, 16.90, 16.20])

fig, ax = plt.subplots(2, 2, figsize=(12, 8), dpi=300)

# Base
ax[0, 0].errorbar(t, base_1, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P1:.2f} W')
ax[0, 0].errorbar(t, base_2, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P2:.2f} W')
ax[0, 0].errorbar(t, base_3, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P3:.2f} W')
ax[0, 0].set_title('Temperatura en la base')
ax[0, 0].set_xlabel('Tiempo [s]')
ax[0, 0].set_ylabel('Temperatura [°C]')
ax[0, 0].grid(True)
ax[0, 0].legend()

# Punta
ax[0, 1].errorbar(t, punta_1, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P1:.2f} W')
ax[0, 1].errorbar(t, punta_2, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P2:.2f} W')
ax[0, 1].errorbar(t, punta_3, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P3:.2f} W')
ax[0, 1].set_title('Temperatura en la punta')
ax[0, 1].set_xlabel('Tiempo [s]')
ax[0, 1].set_ylabel('Temperatura [°C]')
ax[0, 1].grid(True)
ax[0, 1].legend()

# Superficie
ax[1, 0].errorbar(t, superficie_1, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P1:.2f} W')
ax[1, 0].errorbar(t, superficie_2, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P2:.2f} W')
ax[1, 0].errorbar(t, superficie_3, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P3:.2f} W')
ax[1, 0].set_title('Temperatura en la superficie')
ax[1, 0].set_xlabel('Tiempo [s]')
ax[1, 0].set_ylabel('Temperatura [°C]')
ax[1, 0].grid(True)
ax[1, 0].legend()

# Aire
ax[1, 1].errorbar(t, aire_1, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P1:.2f} W')
ax[1, 1].errorbar(t, aire_2, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P2:.2f} W')
ax[1, 1].errorbar(t, aire_3, yerr=dT, xerr=dt, marker='o', markersize=3, capsize=2, label=f'{P3:.2f} W')
ax[1, 1].set_title('Temperatura del aire alrededor')
ax[1, 1].set_xlabel('Tiempo [s]')
ax[1, 1].set_ylabel('Temperatura [°C]')
ax[1, 1].grid(True)
ax[1, 1].legend()

fig.suptitle('Comparación del comportamiento térmico para las tres potencias', fontsize=14)
plt.tight_layout()
plt.show()
